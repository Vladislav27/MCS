# %%
import numpy as np
import matplotlib.pyplot as plt

#a = 0, b = 100, x = 50, p = 0.5, P = 1, 2, 4, 8, 16

p = np.array([1, 2, 4, 8, 16])
t_p = np.array([0.0472, 0.0344, 0.0305, 0.035, 0.0246])
s_p = np.array([1, 1.309, 1.59, 1.4, 1.91])
e_p = np.array([1, 0.6501, 0.391, 0.171, 0.1165])

plt.title("T(P)")
plt.plot(p, t_p)
plt.show()

plt.title("S(P)")
plt.plot(p, s_p)
plt.show()

plt.title("E(P)")
plt.plot(p, e_p)
plt.show()
